# %%
import cv2
import os

# %%
pic_path='/media/sdu/Elements/lixiang/数据集/滨州数据/20190412挑选/'
save_path='/media/sdu/Elements/lixiang/数据集/滨州数据/20190412挑选/'
resize_h=375
resize_w=500

# %%
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
index=125000
for (path,dirnames,filenames) in os.walk(pic_path):
    for filename in filenames:
        if filename.endswith('.jpg'):
            print('正在处理第 %s 张图片' % index)
            img_path = path + '/' + filename
            img = cv2.imread(img_path)
            new_img = cv2.resize(img,(resize_w,resize_h))
            cv2.imwrite(save_path + '/' + str(index) + '.jpeg', new_img)
            index += 1
            key = cv2.waitKey(30) & 0xff
            if key == 27:
                sys.exit(0)
# Out:
# 正在处理第 125000 张图片
# 正在处理第 125001 张图片
# 正在处理第 125002 张图片
# 正在处理第 125003 张图片
# 正在处理第 125004 张图片
# 正在处理第 125005 张图片
# 正在处理第 125006 张图片
# 正在处理第 125007 张图片
# 正在处理第 125008 张图片
# 正在处理第 125009 张图片
# 正在处理第 125010 张图片
# 正在处理第 125011 张图片
# 正在处理第 125012 张图片
# 正在处理第 125013 张图片
# 正在处理第 125014 张图片
# 正在处理第 125015 张图片
# 正在处理第 125016 张图片
# 正在处理第 125017 张图片
# 正在处理第 125018 张图片
# 正在处理第 125019 张图片
# 正在处理第 125020 张图片
# 正在处理第 125021 张图片
# 正在处理第 125022 张图片
# 正在处理第 125023 张图片
# 正在处理第 125024 张图片
# 正在处理第 125025 张图片
# 正在处理第 125026 张图片
# 正在处理第 125027 张图片
# 正在处理第 125028 张图片
# 正在处理第 125029 张图片
# 正在处理第 125030 张图片
# 正在处理第 125031 张图片
# 正在处理第 125032 张图片
# 正在处理第 125033 张图片
# 正在处理第 125034 张图片
# 正在处理第 125035 张图片
# 正在处理第 125036 张图片
# 正在处理第 125037 张图片
# 正在处理第 125038 张图片
# 正在处理第 125039 张图片
# 正在处理第 125040 张图片
# 正在处理第 125041 张图片
# 正在处理第 125042 张图片
# 正在处理第 125043 张图片
# 正在处理第 125044 张图片
# 正在处理第 125045 张图片
# 正在处理第 125046 张图片
# 正在处理第 125047 张图片
# 正在处理第 125048 张图片
# 正在处理第 125049 张图片
# 正在处理第 125050 张图片
# 正在处理第 125051 张图片
# ...
